# %%
# car price predection using meachine learning:

# %%
import numpy as np
import pandas as pd
data=pd.read_csv("CarPrice_Assignment.csv")
data
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
data.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
data.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
data.isna().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
data.dropna(inplace = True)

# %%
data.isna().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
data.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
plt.scatter(data["car_ID"][:300], data["price"][:300])

# %%
plt.scatter(data["symboling"][:300], data["price"][:300])

# %%
for i in data.columns[:-1]:
    plt.xlabel(i)
    plt.ylabel("price")
    plt.scatter(data[i][:300],data["price"][:300])
    plt.show()

# %%
x = np.array(data["car_ID"]).reshape(-1,1)

y = np.array(data["price"]).reshape(-1,1)

# %%
import numpy as np

# %%
from sklearn.linear_model import LinearRegression

# %%
linear = LinearRegression()

# %%
linear.fit(x,y)
# Out:
# LinearRegression()

# %%
linear.predict([[34]])
# Out:
# array([[14290.41607092]])

# %% [markdown]
# # multiple regression:

# %%
len(data.columns)
# Out:
# 26

# %%
data.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
x = data.drop("price",axis=1)
y = data["price"]

# %%
x.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  cylindernumber  \
# 0  convertible        rwd          front       88.6  ...            four
# 1  convertible        rwd          front       88.6  ...            four
# 2    hatchback        rwd          front       94.5  ...             six
# 3        sedan        fwd          front       99.8  ...            four
# 4        sedan        4wd          front       99.4  ...            five
#
# ...

# %%
y.head()
# Out:
# 0    13495.0
# 1    16500.0
# 2    16500.0
# 3    13950.0
# 4    17450.0
# Name: price, dtype: float64

# %%
model = LinearRegression()

# %%
## fltering out numerical columns from the dataset?

data_numerical = data.select_dtypes(include = [np.number])
data_numerical
# include = [np.number]
# Out:
#      car_ID  symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0         1          3       88.6      168.8      64.1       48.8        2548
# 1         2          3       88.6      168.8      64.1       48.8        2548
# 2         3          1       94.5      171.2      65.5       52.4        2823
# 3         4          2       99.8      176.6      66.2       54.3        2337
# 4         5          2       99.4      176.6      66.4       54.3        2824
# ..      ...        ...        ...        ...       ...        ...         ...
# 200     201         -1      109.1      188.8      68.9       55.5        2952
# 201     202         -1      109.1      188.8      68.8       55.5        3049
# 202     203         -1      109.1      188.8      68.9       55.5        3012
# 203     204         -1      109.1      188.8      68.9       55.5        3217
# 204     205         -1      109.1      188.8      68.9       55.5        3062
#
# ...

# %%
model = LinearRegression()

# %%
model.fit(x,y)

# %%
model.coef_

# %%
model.intercept_

# %%
x.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg'],
#       dtype='object')

# %%
model.predict([[3, 5, 2, 5, 16]])

# %%
import seaborn as sns

# %%
sns.regplot(x="car_ID",
           y = "price",
           data = data[:100])
# Out:
# <AxesSubplot:xlabel='car_ID', ylabel='price'>

# %% [markdown]
# # split the data into testing and training

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain , ytest = train_test_split(data.drop("price",axis=1),data["price"], train_size = .75)

# %%
xtrain.shape
# Out:
# (153, 25)

# %%
ytrain.shape
# Out:
# (153,)

# %%
xtest.shape
# Out:
# (52, 25)

# %%
ytest.shape
# Out:
# (52,)

# %%
model = LinearRegression()

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
data["honda accord"]=labelencoder.fit_transform(data["symboling"])
data
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
model.fit(xtrain,ytrain)

# %%
data['wheelbase'] = data['wheelbase'].replace('honda accord', 0)

# %%
data
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
model.fit(xtrain,ytrain)

# %%
 LinearRegression()
# Out:
# LinearRegression()

# %%
y_pred = model.predict(xtest)

# %%
ytest.head(10)
# Out:
# 158     7898.0
# 198    18420.0
# 184     7995.0
# 126    32528.0
# 81      8499.0
# 29     12964.0
# 137    18620.0
# 201    19045.0
# 138     5118.0
# 199    18950.0
# Name: price, dtype: float64

# %%
xtest.head(10)
# Out:
#      car_ID  symboling                    CarName fueltype aspiration  \
# 158     159          0              toyota corona   diesel        std
# 198     199         -2                volvo 264gl      gas      turbo
# 184     185          2       volkswagen model 111   diesel        std
# 126     127          3          porcshce panamera      gas        std
# 81       82          3              mitsubishi g4      gas        std
# 29       30          3  dodge coronet custom (sw)      gas      turbo
# 137     138          2                   saab 99e      gas      turbo
# 201     202         -1                volvo 144ea      gas      turbo
# 138     139          2                     subaru      gas        std
# 199     200         -1               volvo diesel      gas      turbo
#
#     doornumber    carbody drivewheel enginelocation  wheelbase  ...  \
# 158       four      sedan        fwd          front       95.7  ...
# ...

# %%
for i in y_pred[:10]:
    print(i)

# %%
model.score(xtrain, ytrain )

# %%
plt.scatter(xtest["	car_ID"][:100],ytest[:100])
plt.plot(y_pred[:100])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error

# %%
mean_absolute_error(ytest, y_pred)

# %%
mean_squared_error(ytest, y_pred)

# %%
model.score(xtrain,ytrain) #r2 score

# %% [markdown]
# # polynomial regression

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree = 2)

# %%
x = x.reshape(-1,1)

# %%
x_train = poly.fit_transform(x)

# %%
x_train

# %%
x_train.shape

# %%
plt.scatter(x_train[1], x_train[2])

# %%
from sklearn.linear_model import LinearRegression

# %%
lin = LinearRegression()

# %%
poly.fit(x_train,y)

# %%
lin.fit(x_train,y)

# %%
lin.intercept_

# %%
lin.coef_

# %%
plt.scatter(x, lin.predict(x_train))
plt.plot(x, lin.predict(x_train))

# %%
lin.score(x_train,y)

# %%
lin.predict([[1,1,2]])
